# %%
import pathlib
from psql import db, session
from schema import model_config, model_profile, model_run
from datetime import datetime
import re

# %%
file_input_path='./file'
p = pathlib.Path(file_input_path)
f_list = list(p.glob('**/*.txt'))
print(f_list)
# Out:
# [PosixPath('file/20220610112000/timer_36246.txt'), PosixPath('file/20220606/timer_36133_prev.txt'), PosixPath('file/20220606/timer_36133.txt'), PosixPath('file/20220609/timer_36219.txt'), PosixPath('file/20220615025400/timer_36372.txt'), PosixPath('file/20220617234000/timer_36434.txt'), PosixPath('file/20220608/timer_36188.txt'), PosixPath('file/20220607/timer_36151.txt'), PosixPath('file/20220616204200/timer_36392.txt'), PosixPath('file/20220605/timer_36133.txt'), PosixPath('file/20220603/timer_36132.txt'), PosixPath('file/20220603/timer_36132_prev.txt'), PosixPath('file/20220603/timer_36132_prev_2.txt'), PosixPath('file/20220603/20220604/timer_36133.txt')]

# %%
# model configuration
model_name = 'lfric1'
num_procss = '6'
num_thread='1'
model_resolution='c16_dt3600'
configuration='canned'

new_model = model_config(\
    model=model_name, resolution=model_resolution,\
    thread=num_thread, process=num_procss, config=configuration)

# %%
isExist_model = session.query(model_config.id).filter(\
            model_config.model == model_name, \
            model_config.resolution == model_resolution, \
            model_config.thread == num_thread, \
            model_config.process == num_procss, \
            model_config.config == configuration).first()
print(isExist_model)
print(type(isExist_model))
print(isExist_model[0])
print(type(isExist_model[0]))
# Out:
# None
# <class 'NoneType'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/kelly/projects/lfric/lfric/test_orm_upload.ipynb Cell 4' in <cell line: 9>()
#       <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000004?line=6'>7</a> print(isExist_model)
#       <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000004?line=7'>8</a> print(type(isExist_model))
# ----> <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000004?line=8'>9</a> print(isExist_model[0])
#      <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000004?line=9'>10</a> print(type(isExist_model[0]))
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# isExist_model = session.query(model_config.id).filter(\
#             model_config.model == model_name, \
#             model_config.resolution == model_resolution, \
#             model_config.thread == num_thread, \
#             model_config.process == num_procss, \
#             model_config.config == configuration).all()
# print(isExist_model)
# print(type(isExist_model))
# print(isExist_model[0])
# print(type(isExist_model[0]))
# print(isExist_model[0][0])
# print(type(isExist_model[0][0]))
# session.close()
# Out:
# [(2,), (3,)]
# <class 'list'>
# (2,)
# <class 'sqlalchemy.engine.row.Row'>
# 2
# <class 'int'>

# %%
# model configuration
model_name = 'lfric1'
num_procss = '6'
num_thread='1'
model_resolution='c16_dt3600'
configuration='canned'

new_model = model_config(\
    model=model_name, resolution=model_resolution,\
    thread=num_thread, process=num_procss, config=configuration)
    
isExist_model2=[]
isExist_model2 = session.query(model_config.id).filter(\
            model_config.model == model_name, \
            model_config.resolution == model_resolution, \
            model_config.thread == num_thread, \
            model_config.process == num_procss, \
            model_config.config == configuration).one()
#return할 쿼리가 없으면 변수가 존재하지 않는다 그러므로 빈리스트의 변수를 하나 만든다.
# Out:
# ---------------------------------------------------------------------------
# NoResultFound                             Traceback (most recent call last)
# /home/kelly/projects/lfric/lfric/test_orm_upload.ipynb Cell 7' in <cell line: 13>()
#       <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=7'>8</a> new_model = model_config(\
#       <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=8'>9</a>     model=model_name, resolution=model_resolution,\
#      <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=9'>10</a>     thread=num_thread, process=num_procss, config=configuration)
#      <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=11'>12</a> isExist_model2=[]
# ---> <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=12'>13</a> isExist_model2 = session.query(model_config.id).filter(\
#      <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=13'>14</a>             model_config.model == model_name, \
#      <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=14'>15</a>             model_config.resolution == model_resolution, \
#      <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=15'>16</a>             model_config.thread == num_thread, \
#      <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=16'>17</a>             model_config.process == num_procss, \
#      <a href='vscode-notebook-cell:/home/kelly/projects/lfric/lfric/test_orm_upload.ipynb#ch0000010?line=17'>18</a>             model_config.config == configuration).one()
#
# File ~/miniconda3/envs/auto/lib/python3.9/site-packages/sqlalchemy/orm/query.py:2856, in Query.one(self)
#    2838 def one(self):
#    2839     """Return exactly one result or raise an exception.
#    2840
#    2841     Raises ``sqlalchemy.orm.exc.NoResultFound`` if the query selects
#    (...)
#    2854
#    2855     """
# -> 2856     return self._iter().one()
#
# File ~/miniconda3/envs/auto/lib/python3.9/site-packages/sqlalchemy/engine/result.py:1191, in Result.one(self)
#    1164 def one(self):
#    1165     """Return exactly one row or raise an exception.
#    1166
#    1167     Raises :class:`.NoResultFound` if the result returns no
#    (...)
#    1189
#    1190     """
# -> 1191     return self._only_one_row(
#    1192         raise_for_second_row=True, raise_for_none=True, scalar=False
#    1193     )
#
# File ~/miniconda3/envs/auto/lib/python3.9/site-packages/sqlalchemy/engine/result.py:562, in ResultInternal._only_one_row(self, raise_for_second_row, raise_for_none, scalar)
#     560 if row is None:
#     561     if raise_for_none:
# --> 562         raise exc.NoResultFound(
#     563             "No row was found when one was required"
#     564         )
#     565     else:
#     566         return None
#
# NoResultFound: No row was found when one was required

# %%
if isExist_model2 == []:
    session.add(new_model)
    print(f'new model {new_model}')
    session.commit()
# Out:
# new model 0 added
